# %%
import os
import sys

# Get the absolute path to the parent folder
parent_folder = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add the parent folder to sys.path if it's not already included
if parent_folder not in sys.path:
    sys.path.append(parent_folder)

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from agents.sarsa import Sarsa
from agents.qlearning import QLearning
from agents.nn_semigrad_sarsa import NeuralNetworkSarsa
from policies.eps_greedy_policy import EpsGreedy
from policies.softmax_policy import Softmax

from utils.encoding import mc_tile_encoding, no_encode
from utils.utils_fct import plot_moving_averages, process_json

# %%
class SimpleDenseModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.hidden_layer = nn.Linear(hidden_size, hidden_size)
        self.output_layer = nn.Linear(hidden_size, output_size)
        self.leaky_relu = nn.LeakyReLU()

    def forward(self, x):
        x = self.input_layer(x)
        x = self.leaky_relu(x)
        x = self.hidden_layer(x)
        x = self.leaky_relu(x)
        return self.output_layer(x)


model = SimpleDenseModel(3, 8, 1)

# %%
env = gym.make("MountainCar-v0", render_mode=None)

neural_network_sarsa = NeuralNetworkSarsa(
    nb_actions=env.action_space.n,
    encode_fct=no_encode,
    policy=EpsGreedy(0.4),
    model=SimpleDenseModel(input_size=3, hidden_size=64, output_size=1),
    optimizer=optim.Adam,
    loss=nn.MSELoss(),
)

_ = neural_network_sarsa.train(
    env=env,
    alpha=0.001,
    gamma=1,
    policy_action_params={},
    policy_update_params={"use_glei": True, "update_frequency": 20},
    network_update_frequency=1,
    nb_episodes=20000,
    verbose=2,
)
_ = neural_network_sarsa.evaluate_policy(
    env=env, policy_action_params={"hard_policy": True}, nb_episodes=10, verbose=1
)
# Out:
# Episode 1: Total Reward = -200.0
# Episode 2: Total Reward = -200.0
# Episode 3: Total Reward = -200.0
# Episode 4: Total Reward = -200.0
# Episode 5: Total Reward = -200.0
# Episode 6: Total Reward = -200.0
# Episode 7: Total Reward = -200.0
# Episode 8: Total Reward = -200.0
# Episode 9: Total Reward = -200.0
# Episode 10: Total Reward = -200.0
# Episode 11: Total Reward = -200.0
# Episode 12: Total Reward = -200.0
# Episode 13: Total Reward = -200.0
# Episode 14: Total Reward = -200.0
# Episode 15: Total Reward = -200.0
# Episode 16: Total Reward = -200.0
# Episode 17: Total Reward = -200.0
# Episode 18: Total Reward = -200.0
# Episode 19: Total Reward = -200.0
# Episode 20: Total Reward = -200.0
# Episode 21: Total Reward = -200.0
# Episode 22: Total Reward = -200.0
# Episode 23: Total Reward = -200.0
# Episode 24: Total Reward = -200.0
# Episode 25: Total Reward = -200.0
# Episode 26: Total Reward = -200.0
# Episode 27: Total Reward = -200.0
# Episode 28: Total Reward = -200.0
# Episode 29: Total Reward = -200.0
# Episode 30: Total Reward = -200.0
# Episode 31: Total Reward = -200.0
# Episode 32: Total Reward = -200.0
# Episode 33: Total Reward = -200.0
# Episode 34: Total Reward = -200.0
# Episode 35: Total Reward = -200.0
# Episode 36: Total Reward = -200.0
# Episode 37: Total Reward = -200.0
# Episode 38: Total Reward = -200.0
# Episode 39: Total Reward = -200.0
# Episode 40: Total Reward = -200.0
# Episode 41: Total Reward = -200.0
# Episode 42: Total Reward = -200.0
# Episode 43: Total Reward = -200.0
# Episode 44: Total Reward = -200.0
# Episode 45: Total Reward = -200.0
# Episode 46: Total Reward = -200.0
# Episode 47: Total Reward = -200.0
# Episode 48: Total Reward = -200.0
# Episode 49: Total Reward = -200.0
# Episode 50: Total Reward = -200.0
# Episode 51: Total Reward = -200.0
# Episode 52: Total Reward = -200.0
# Episode 53: Total Reward = -200.0
# Episode 54: Total Reward = -200.0
# Episode 55: Total Reward = -200.0
# Episode 56: Total Reward = -200.0
# Episode 57: Total Reward = -200.0
# Episode 58: Total Reward = -200.0
# Episode 59: Total Reward = -200.0
# Episode 60: Total Reward = -200.0
# Episode 61: Total Reward = -200.0
# Episode 62: Total Reward = -200.0
# Episode 63: Total Reward = -200.0
# Episode 64: Total Reward = -200.0
# Episode 65: Total Reward = -200.0
# Episode 66: Total Reward = -200.0
# Episode 67: Total Reward = -200.0
# Episode 68: Total Reward = -200.0
# Episode 69: Total Reward = -200.0
# Episode 70: Total Reward = -200.0
# Episode 71: Total Reward = -200.0
# Episode 72: Total Reward = -200.0
# Episode 73: Total Reward = -200.0
# Episode 74: Total Reward = -200.0
# Episode 75: Total Reward = -200.0
# Episode 76: Total Reward = -200.0
# Episode 77: Total Reward = -200.0
# Episode 78: Total Reward = -200.0
# Episode 79: Total Reward = -200.0
# Episode 80: Total Reward = -200.0
# Episode 81: Total Reward = -200.0
# Episode 82: Total Reward = -200.0
# Episode 83: Total Reward = -200.0
# Episode 84: Total Reward = -200.0
# Episode 85: Total Reward = -200.0
# Episode 86: Total Reward = -200.0
# Episode 87: Total Reward = -200.0
# Episode 88: Total Reward = -200.0
# Episode 89: Total Reward = -200.0
# Episode 90: Total Reward = -200.0
# Episode 91: Total Reward = -200.0
# Episode 92: Total Reward = -200.0
# Episode 93: Total Reward = -200.0
# Episode 94: Total Reward = -200.0
# Episode 95: Total Reward = -200.0
# Episode 96: Total Reward = -200.0
# Episode 97: Total Reward = -200.0
# Episode 98: Total Reward = -200.0
# Episode 99: Total Reward = -200.0
# Episode 100: Total Reward = -200.0
# Episode 101: Total Reward = -200.0
# Episode 102: Total Reward = -200.0
# Episode 103: Total Reward = -200.0
# Episode 104: Total Reward = -200.0
# Episode 105: Total Reward = -200.0
# Episode 106: Total Reward = -200.0
# Episode 107: Total Reward = -200.0
# Episode 108: Total Reward = -200.0
# Episode 109: Total Reward = -200.0
# Episode 110: Total Reward = -200.0
# Episode 111: Total Reward = -200.0
# Episode 112: Total Reward = -200.0
# Episode 113: Total Reward = -200.0
# Episode 114: Total Reward = -200.0
# Episode 115: Total Reward = -200.0
# Episode 116: Total Reward = -200.0
# Episode 117: Total Reward = -200.0
# Episode 118: Total Reward = -200.0
# Episode 119: Total Reward = -200.0
# Episode 120: Total Reward = -200.0
# Episode 121: Total Reward = -200.0
# Episode 122: Total Reward = -200.0
# Episode 123: Total Reward = -200.0
# Episode 124: Total Reward = -200.0
# Episode 125: Total Reward = -200.0
# Episode 126: Total Reward = -200.0
# Episode 127: Total Reward = -200.0
# Episode 128: Total Reward = -200.0
# Episode 129: Total Reward = -200.0
# Episode 130: Total Reward = -200.0
# Episode 131: Total Reward = -200.0
# Episode 132: Total Reward = -200.0
# Episode 133: Total Reward = -200.0
# Episode 134: Total Reward = -200.0
# Episode 135: Total Reward = -200.0
# Episode 136: Total Reward = -200.0
# Episode 137: Total Reward = -200.0
# Episode 138: Total Reward = -200.0
# Episode 139: Total Reward = -200.0
# Episode 140: Total Reward = -200.0
# Episode 141: Total Reward = -200.0
# Episode 142: Total Reward = -200.0
# Episode 143: Total Reward = -200.0
# Episode 144: Total Reward = -200.0
# Episode 145: Total Reward = -200.0
# Episode 146: Total Reward = -200.0
# Episode 147: Total Reward = -200.0
# Episode 148: Total Reward = -200.0
# Episode 149: Total Reward = -200.0
# Episode 150: Total Reward = -200.0
# Episode 151: Total Reward = -200.0
# Episode 152: Total Reward = -200.0
# Episode 153: Total Reward = -200.0
# Episode 154: Total Reward = -200.0
# Episode 155: Total Reward = -200.0
# Episode 156: Total Reward = -200.0
# Episode 157: Total Reward = -200.0
# Episode 158: Total Reward = -200.0
# Episode 159: Total Reward = -200.0
# Episode 160: Total Reward = -200.0
# Episode 161: Total Reward = -200.0
# Episode 162: Total Reward = -200.0
# Episode 163: Total Reward = -200.0
# Episode 164: Total Reward = -200.0
# Episode 165: Total Reward = -200.0
# Episode 166: Total Reward = -200.0
# Episode 167: Total Reward = -200.0
# Episode 168: Total Reward = -200.0
# Episode 169: Total Reward = -200.0
# Episode 170: Total Reward = -200.0
# Episode 171: Total Reward = -200.0
# Episode 172: Total Reward = -200.0
# Episode 173: Total Reward = -200.0
# Episode 174: Total Reward = -200.0
# Episode 175: Total Reward = -200.0
# Episode 176: Total Reward = -200.0
# Episode 177: Total Reward = -200.0
# Episode 178: Total Reward = -200.0
# Episode 179: Total Reward = -200.0
# Episode 180: Total Reward = -200.0
# Episode 181: Total Reward = -200.0
# Episode 182: Total Reward = -200.0
# Episode 183: Total Reward = -200.0
# Episode 184: Total Reward = -200.0
# Episode 185: Total Reward = -200.0
# Episode 186: Total Reward = -200.0
# Episode 187: Total Reward = -200.0
# Episode 188: Total Reward = -200.0
# Episode 189: Total Reward = -200.0
# Episode 190: Total Reward = -200.0
# Episode 191: Total Reward = -200.0
# Episode 192: Total Reward = -200.0
# Episode 193: Total Reward = -200.0
# Episode 194: Total Reward = -200.0
# Episode 195: Total Reward = -200.0
# Episode 196: Total Reward = -200.0
# Episode 197: Total Reward = -200.0
# Episode 198: Total Reward = -200.0
# Episode 199: Total Reward = -200.0
# Episode 200: Total Reward = -200.0
# Episode 201: Total Reward = -200.0
# Episode 202: Total Reward = -200.0
# Episode 203: Total Reward = -200.0
# Episode 204: Total Reward = -200.0
# Episode 205: Total Reward = -200.0
# Episode 206: Total Reward = -200.0
# Episode 207: Total Reward = -200.0
# Episode 208: Total Reward = -200.0
# Episode 209: Total Reward = -200.0
# Episode 210: Total Reward = -200.0
# Episode 211: Total Reward = -200.0
# Episode 212: Total Reward = -200.0
# Episode 213: Total Reward = -200.0
# Episode 214: Total Reward = -200.0
# Episode 215: Total Reward = -200.0
# Episode 216: Total Reward = -200.0
# Episode 217: Total Reward = -200.0
# Episode 218: Total Reward = -200.0
# Episode 219: Total Reward = -200.0
# Episode 220: Total Reward = -200.0
# Episode 221: Total Reward = -200.0
# Episode 222: Total Reward = -200.0
# Episode 223: Total Reward = -200.0
# Episode 224: Total Reward = -200.0
# Episode 225: Total Reward = -200.0
# Episode 226: Total Reward = -200.0
# Episode 227: Total Reward = -200.0
# Episode 228: Total Reward = -200.0
# Episode 229: Total Reward = -200.0
# Episode 230: Total Reward = -200.0
# Episode 231: Total Reward = -200.0
# Episode 232: Total Reward = -200.0
# Episode 233: Total Reward = -200.0
# Episode 234: Total Reward = -200.0
# Episode 235: Total Reward = -200.0
# Episode 236: Total Reward = -200.0
# Episode 237: Total Reward = -200.0
# Episode 238: Total Reward = -200.0
# Episode 239: Total Reward = -200.0
# Episode 240: Total Reward = -200.0
# Episode 241: Total Reward = -200.0
# Episode 242: Total Reward = -200.0
# Episode 243: Total Reward = -200.0
# Episode 244: Total Reward = -200.0
# Episode 245: Total Reward = -200.0
# Episode 246: Total Reward = -200.0
# Episode 247: Total Reward = -200.0
# Episode 248: Total Reward = -200.0
# Episode 249: Total Reward = -200.0
# Episode 250: Total Reward = -200.0
# Episode 251: Total Reward = -200.0
# Episode 252: Total Reward = -200.0
# Episode 253: Total Reward = -200.0
# Episode 254: Total Reward = -200.0
# Episode 255: Total Reward = -200.0
# Episode 256: Total Reward = -200.0
# Episode 257: Total Reward = -200.0
# Episode 258: Total Reward = -200.0
# Episode 259: Total Reward = -200.0
# Episode 260: Total Reward = -200.0
# Episode 261: Total Reward = -200.0
# Episode 262: Total Reward = -200.0
# Episode 263: Total Reward = -200.0
# Episode 264: Total Reward = -200.0
# Episode 265: Total Reward = -200.0
# Episode 266: Total Reward = -200.0
# Episode 267: Total Reward = -200.0
# Episode 268: Total Reward = -200.0
# Episode 269: Total Reward = -200.0
# Episode 270: Total Reward = -200.0
# Episode 271: Total Reward = -200.0
# Episode 272: Total Reward = -200.0
# Episode 273: Total Reward = -200.0
# Episode 274: Total Reward = -200.0
# Episode 275: Total Reward = -200.0
# Episode 276: Total Reward = -200.0
# Episode 277: Total Reward = -200.0
# Episode 278: Total Reward = -200.0
# Episode 279: Total Reward = -200.0
# Episode 280: Total Reward = -200.0
# Episode 281: Total Reward = -200.0
# Episode 282: Total Reward = -200.0
# Episode 283: Total Reward = -200.0
# Episode 284: Total Reward = -200.0
# Episode 285: Total Reward = -200.0
# Episode 286: Total Reward = -200.0
# Episode 287: Total Reward = -200.0
# Episode 288: Total Reward = -200.0
# Episode 289: Total Reward = -200.0
# Episode 290: Total Reward = -200.0
# Episode 291: Total Reward = -200.0
# Episode 292: Total Reward = -200.0
# Episode 293: Total Reward = -200.0
# Episode 294: Total Reward = -200.0
# Episode 295: Total Reward = -200.0
# Episode 296: Total Reward = -200.0
# Episode 297: Total Reward = -200.0
# Episode 298: Total Reward = -200.0
# Episode 299: Total Reward = -200.0
# Episode 300: Total Reward = -200.0
# Episode 301: Total Reward = -200.0
# Episode 302: Total Reward = -200.0
# Episode 303: Total Reward = -200.0
# Episode 304: Total Reward = -200.0
# Episode 305: Total Reward = -200.0
# Episode 306: Total Reward = -200.0
# Episode 307: Total Reward = -200.0
# Episode 308: Total Reward = -200.0
# Episode 309: Total Reward = -200.0
# Episode 310: Total Reward = -200.0
# Episode 311: Total Reward = -200.0
# Episode 312: Total Reward = -200.0
# Episode 313: Total Reward = -200.0
# Episode 314: Total Reward = -200.0
# Episode 315: Total Reward = -200.0
# Episode 316: Total Reward = -200.0
# Episode 317: Total Reward = -200.0
# Episode 318: Total Reward = -200.0
# Episode 319: Total Reward = -200.0
# Episode 320: Total Reward = -200.0
# Episode 321: Total Reward = -200.0
# Episode 322: Total Reward = -200.0
# Episode 323: Total Reward = -200.0
# Episode 324: Total Reward = -200.0
# Episode 325: Total Reward = -200.0
# Episode 326: Total Reward = -200.0
# Episode 327: Total Reward = -200.0
# Episode 328: Total Reward = -200.0
# Episode 329: Total Reward = -200.0
# Episode 330: Total Reward = -200.0
# Episode 331: Total Reward = -200.0
# Episode 332: Total Reward = -200.0
# Episode 333: Total Reward = -200.0
# Episode 334: Total Reward = -200.0
# Episode 335: Total Reward = -200.0
# Episode 336: Total Reward = -200.0
# Episode 337: Total Reward = -200.0
# Episode 338: Total Reward = -200.0
# Episode 339: Total Reward = -200.0
# Episode 340: Total Reward = -200.0
# Episode 341: Total Reward = -200.0
# Episode 342: Total Reward = -200.0
# Episode 343: Total Reward = -200.0
# Episode 344: Total Reward = -200.0
# Episode 345: Total Reward = -200.0
# Episode 346: Total Reward = -200.0
# Episode 347: Total Reward = -200.0
# Episode 348: Total Reward = -200.0
# Episode 349: Total Reward = -200.0
# Episode 350: Total Reward = -200.0
# Episode 351: Total Reward = -200.0
# Episode 352: Total Reward = -200.0
# Episode 353: Total Reward = -200.0
# Episode 354: Total Reward = -200.0
# Episode 355: Total Reward = -200.0
# Episode 356: Total Reward = -200.0
# Episode 357: Total Reward = -200.0
# Episode 358: Total Reward = -200.0
# Episode 359: Total Reward = -200.0
# Episode 360: Total Reward = -200.0
# Episode 361: Total Reward = -200.0
# Episode 362: Total Reward = -200.0
# Episode 363: Total Reward = -200.0
# Episode 364: Total Reward = -200.0
# Episode 365: Total Reward = -200.0
# Episode 366: Total Reward = -200.0
# Episode 367: Total Reward = -200.0
# Episode 368: Total Reward = -200.0
# Episode 369: Total Reward = -200.0
# Episode 370: Total Reward = -200.0
# Episode 371: Total Reward = -200.0
# Episode 372: Total Reward = -200.0
# Episode 373: Total Reward = -200.0
# Episode 374: Total Reward = -200.0
# Episode 375: Total Reward = -200.0
# Episode 376: Total Reward = -200.0
# Episode 377: Total Reward = -200.0
# Episode 378: Total Reward = -200.0
# Episode 379: Total Reward = -200.0
# Episode 380: Total Reward = -200.0
# Episode 381: Total Reward = -200.0
# Episode 382: Total Reward = -200.0
# Episode 383: Total Reward = -200.0
# Episode 384: Total Reward = -200.0
# Episode 385: Total Reward = -200.0
# Episode 386: Total Reward = -200.0
# Episode 387: Total Reward = -200.0
# Episode 388: Total Reward = -200.0
# Episode 389: Total Reward = -200.0
# Episode 390: Total Reward = -200.0
# Episode 391: Total Reward = -200.0
# Episode 392: Total Reward = -200.0
# Episode 393: Total Reward = -200.0
# Episode 394: Total Reward = -200.0
# Episode 395: Total Reward = -200.0
# Episode 396: Total Reward = -200.0
# Episode 397: Total Reward = -200.0
# Episode 398: Total Reward = -200.0
# Episode 399: Total Reward = -200.0
# Episode 400: Total Reward = -200.0
# Episode 401: Total Reward = -200.0
# Episode 402: Total Reward = -200.0
# Episode 403: Total Reward = -200.0
# Episode 404: Total Reward = -200.0
# Episode 405: Total Reward = -200.0
# Episode 406: Total Reward = -200.0
# Episode 407: Total Reward = -200.0
# Episode 408: Total Reward = -200.0
# Episode 409: Total Reward = -200.0
# Episode 410: Total Reward = -200.0
# Episode 411: Total Reward = -200.0
# Episode 412: Total Reward = -200.0
# Episode 413: Total Reward = -200.0
# Episode 414: Total Reward = -200.0
# Episode 415: Total Reward = -200.0
# Episode 416: Total Reward = -200.0
# Episode 417: Total Reward = -200.0
# Episode 418: Total Reward = -200.0
# Episode 419: Total Reward = -200.0
# Episode 420: Total Reward = -200.0
# Episode 421: Total Reward = -200.0
# Episode 422: Total Reward = -200.0
# Episode 423: Total Reward = -200.0
# Episode 424: Total Reward = -200.0
# Episode 425: Total Reward = -200.0
# Episode 426: Total Reward = -200.0
# Episode 427: Total Reward = -200.0
# Episode 428: Total Reward = -200.0
# Episode 429: Total Reward = -200.0
# Episode 430: Total Reward = -200.0
# Episode 431: Total Reward = -200.0
# Episode 432: Total Reward = -200.0
# Episode 433: Total Reward = -200.0
# Episode 434: Total Reward = -200.0
# Episode 435: Total Reward = -200.0
# Episode 436: Total Reward = -200.0
# Episode 437: Total Reward = -200.0
# Episode 438: Total Reward = -200.0
# Episode 439: Total Reward = -200.0
# Episode 440: Total Reward = -200.0
# Episode 441: Total Reward = -200.0
# Episode 442: Total Reward = -200.0
# Episode 443: Total Reward = -200.0
# Episode 444: Total Reward = -200.0
# Episode 445: Total Reward = -200.0
# Episode 446: Total Reward = -200.0
# Episode 447: Total Reward = -200.0
# Episode 448: Total Reward = -200.0
# Episode 449: Total Reward = -200.0
# Episode 450: Total Reward = -200.0
# Episode 451: Total Reward = -200.0
# Episode 452: Total Reward = -200.0
# Episode 453: Total Reward = -200.0
# Episode 454: Total Reward = -200.0
# Episode 455: Total Reward = -200.0
# Episode 456: Total Reward = -200.0
# Episode 457: Total Reward = -200.0
# Episode 458: Total Reward = -200.0
# Episode 459: Total Reward = -200.0
# Episode 460: Total Reward = -200.0
# Episode 461: Total Reward = -200.0
# Episode 462: Total Reward = -200.0
# Episode 463: Total Reward = -200.0
# Episode 464: Total Reward = -200.0
# Episode 465: Total Reward = -200.0
# Episode 466: Total Reward = -200.0
# Episode 467: Total Reward = -200.0
# Episode 468: Total Reward = -200.0
# Episode 469: Total Reward = -200.0
# Episode 470: Total Reward = -200.0
# Episode 471: Total Reward = -200.0
# Episode 472: Total Reward = -200.0
# Episode 473: Total Reward = -200.0
# Episode 474: Total Reward = -200.0
# Episode 475: Total Reward = -200.0
# Episode 476: Total Reward = -200.0
# Episode 477: Total Reward = -200.0
# Episode 478: Total Reward = -200.0
# Episode 479: Total Reward = -200.0
# Episode 480: Total Reward = -200.0
# Episode 481: Total Reward = -200.0
# Episode 482: Total Reward = -200.0
# Episode 483: Total Reward = -200.0
# Episode 484: Total Reward = -200.0
# Episode 485: Total Reward = -200.0
# Episode 486: Total Reward = -200.0
# Episode 487: Total Reward = -200.0
# Episode 488: Total Reward = -200.0
# Episode 489: Total Reward = -200.0
# Episode 490: Total Reward = -200.0
# Episode 491: Total Reward = -200.0
# Episode 492: Total Reward = -200.0
# Episode 493: Total Reward = -200.0
# Episode 494: Total Reward = -200.0
# Episode 495: Total Reward = -200.0
# Episode 496: Total Reward = -200.0
# Episode 497: Total Reward = -200.0
# Episode 498: Total Reward = -200.0
# Episode 499: Total Reward = -200.0
# Episode 500: Total Reward = -200.0
# Episode 501: Total Reward = -200.0
# Episode 502: Total Reward = -200.0
# Episode 503: Total Reward = -200.0
# Episode 504: Total Reward = -200.0
# Episode 505: Total Reward = -200.0
# Episode 506: Total Reward = -200.0
# Episode 507: Total Reward = -200.0
# Episode 508: Total Reward = -200.0
# Episode 509: Total Reward = -200.0
# Episode 510: Total Reward = -200.0
# Episode 511: Total Reward = -200.0
# Episode 512: Total Reward = -200.0
# Episode 513: Total Reward = -200.0
# Episode 514: Total Reward = -200.0
# Episode 515: Total Reward = -200.0
# Episode 516: Total Reward = -200.0
# Episode 517: Total Reward = -200.0
# Episode 518: Total Reward = -200.0
# Episode 519: Total Reward = -200.0
# Episode 520: Total Reward = -200.0
# Episode 521: Total Reward = -200.0
# Episode 522: Total Reward = -200.0
# Episode 523: Total Reward = -200.0
# Episode 524: Total Reward = -200.0
# Episode 525: Total Reward = -200.0
# Episode 526: Total Reward = -200.0
# Episode 527: Total Reward = -200.0
# Episode 528: Total Reward = -200.0
# Episode 529: Total Reward = -200.0
# Episode 530: Total Reward = -200.0
# Episode 531: Total Reward = -200.0
# Episode 532: Total Reward = -200.0
# Episode 533: Total Reward = -200.0
# Episode 534: Total Reward = -200.0
# Episode 535: Total Reward = -200.0
# Episode 536: Total Reward = -200.0
# Episode 537: Total Reward = -200.0
# Episode 538: Total Reward = -200.0
# Episode 539: Total Reward = -200.0
# Episode 540: Total Reward = -200.0
# Episode 541: Total Reward = -200.0
# Episode 542: Total Reward = -200.0
# Episode 543: Total Reward = -200.0
# Episode 544: Total Reward = -200.0
# Episode 545: Total Reward = -200.0
# Episode 546: Total Reward = -200.0
# Episode 547: Total Reward = -200.0
# Episode 548: Total Reward = -200.0
# Episode 549: Total Reward = -200.0
# Episode 550: Total Reward = -200.0
# Episode 551: Total Reward = -200.0
# Episode 552: Total Reward = -200.0
# Episode 553: Total Reward = -200.0
# Episode 554: Total Reward = -200.0
# Episode 555: Total Reward = -200.0
# Episode 556: Total Reward = -200.0
# Episode 557: Total Reward = -200.0
# Episode 558: Total Reward = -200.0
# Episode 559: Total Reward = -200.0
# Episode 560: Total Reward = -200.0
# Episode 561: Total Reward = -200.0
# Episode 562: Total Reward = -200.0
# Episode 563: Total Reward = -200.0
# Episode 564: Total Reward = -200.0
# Episode 565: Total Reward = -200.0
# Episode 566: Total Reward = -200.0
# Episode 567: Total Reward = -200.0
# Episode 568: Total Reward = -200.0
# Episode 569: Total Reward = -200.0
# Episode 570: Total Reward = -200.0
# Episode 571: Total Reward = -200.0
# Episode 572: Total Reward = -200.0
# Episode 573: Total Reward = -200.0
# Episode 574: Total Reward = -200.0
# Episode 575: Total Reward = -200.0
# Episode 576: Total Reward = -200.0
# Episode 577: Total Reward = -200.0
# Episode 578: Total Reward = -200.0
# Episode 579: Total Reward = -200.0
# Episode 580: Total Reward = -200.0
# Episode 581: Total Reward = -200.0
# Episode 582: Total Reward = -200.0
# Episode 583: Total Reward = -200.0
# Episode 584: Total Reward = -200.0
# Episode 585: Total Reward = -200.0
# Episode 586: Total Reward = -200.0
# Episode 587: Total Reward = -200.0
# Episode 588: Total Reward = -200.0
# Episode 589: Total Reward = -200.0
# Episode 590: Total Reward = -200.0
# Episode 591: Total Reward = -200.0
# Episode 592: Total Reward = -200.0
# Episode 593: Total Reward = -200.0
# Episode 594: Total Reward = -200.0
# Episode 595: Total Reward = -200.0
# Episode 596: Total Reward = -200.0
# Episode 597: Total Reward = -200.0
# Episode 598: Total Reward = -200.0
# Episode 599: Total Reward = -200.0
# Episode 600: Total Reward = -200.0
# Episode 601: Total Reward = -200.0
# Episode 602: Total Reward = -200.0
# Episode 603: Total Reward = -200.0
# Episode 604: Total Reward = -200.0
# Episode 605: Total Reward = -200.0
# Episode 606: Total Reward = -200.0
# Episode 607: Total Reward = -200.0
# Episode 608: Total Reward = -200.0
# Episode 609: Total Reward = -200.0
# Episode 610: Total Reward = -200.0
# Episode 611: Total Reward = -200.0
# Episode 612: Total Reward = -200.0
# Episode 613: Total Reward = -200.0
# Episode 614: Total Reward = -200.0
# Episode 615: Total Reward = -200.0
# Episode 616: Total Reward = -200.0
# Episode 617: Total Reward = -200.0
# Episode 618: Total Reward = -200.0
# Episode 619: Total Reward = -200.0
# Episode 620: Total Reward = -200.0
# Episode 621: Total Reward = -200.0
# Episode 622: Total Reward = -200.0
# Episode 623: Total Reward = -200.0
# Episode 624: Total Reward = -200.0
# Episode 625: Total Reward = -200.0
# Episode 626: Total Reward = -200.0
# Episode 627: Total Reward = -200.0
# Episode 628: Total Reward = -200.0
# Episode 629: Total Reward = -200.0
# Episode 630: Total Reward = -200.0
# Episode 631: Total Reward = -200.0
# Episode 632: Total Reward = -200.0
# Episode 633: Total Reward = -200.0
# Episode 634: Total Reward = -200.0
# Episode 635: Total Reward = -200.0
# Episode 636: Total Reward = -200.0
# Episode 637: Total Reward = -200.0
# Episode 638: Total Reward = -200.0
# Episode 639: Total Reward = -200.0
# Episode 640: Total Reward = -200.0
# Episode 641: Total Reward = -200.0
# Episode 642: Total Reward = -200.0
# Episode 643: Total Reward = -200.0
# Episode 644: Total Reward = -200.0
# Episode 645: Total Reward = -200.0
# Episode 646: Total Reward = -200.0
# Episode 647: Total Reward = -200.0
# Episode 648: Total Reward = -200.0
# Episode 649: Total Reward = -200.0
# Episode 650: Total Reward = -200.0
# Episode 651: Total Reward = -200.0
# Episode 652: Total Reward = -200.0
# Episode 653: Total Reward = -200.0
# Episode 654: Total Reward = -200.0
# Episode 655: Total Reward = -200.0
# Episode 656: Total Reward = -200.0
# Episode 657: Total Reward = -200.0
# Episode 658: Total Reward = -200.0
# Episode 659: Total Reward = -200.0
# Episode 660: Total Reward = -200.0
# Episode 661: Total Reward = -200.0
# Episode 662: Total Reward = -200.0
# Episode 663: Total Reward = -200.0
# Episode 664: Total Reward = -200.0
# Episode 665: Total Reward = -200.0
# Episode 666: Total Reward = -200.0
# Episode 667: Total Reward = -200.0
# Episode 668: Total Reward = -200.0
# Episode 669: Total Reward = -200.0
# Episode 670: Total Reward = -200.0
# Episode 671: Total Reward = -200.0
# Episode 672: Total Reward = -200.0
# Episode 673: Total Reward = -200.0
# Episode 674: Total Reward = -200.0
# Episode 675: Total Reward = -200.0
# Episode 676: Total Reward = -200.0
# Episode 677: Total Reward = -200.0
# Episode 678: Total Reward = -200.0
# Episode 679: Total Reward = -200.0
# Episode 680: Total Reward = -200.0
# Episode 681: Total Reward = -200.0
# Episode 682: Total Reward = -200.0
# Episode 683: Total Reward = -200.0
# Episode 684: Total Reward = -200.0
# Episode 685: Total Reward = -200.0
# Episode 686: Total Reward = -200.0
# Episode 687: Total Reward = -200.0
# Episode 688: Total Reward = -200.0
# Episode 689: Total Reward = -200.0
# Episode 690: Total Reward = -200.0
# Episode 691: Total Reward = -200.0
# Episode 692: Total Reward = -200.0
# Episode 693: Total Reward = -200.0
# Episode 694: Total Reward = -200.0
# Episode 695: Total Reward = -200.0
# Episode 696: Total Reward = -200.0
# Episode 697: Total Reward = -200.0
# Episode 698: Total Reward = -200.0
# Episode 699: Total Reward = -200.0
# Episode 700: Total Reward = -200.0
# Episode 701: Total Reward = -200.0
# Episode 702: Total Reward = -200.0
# Episode 703: Total Reward = -200.0
# Episode 704: Total Reward = -200.0
# Episode 705: Total Reward = -200.0
# Episode 706: Total Reward = -200.0
# Episode 707: Total Reward = -200.0
# Episode 708: Total Reward = -200.0
# Episode 709: Total Reward = -200.0
# Episode 710: Total Reward = -200.0
# Episode 711: Total Reward = -200.0
# Episode 712: Total Reward = -200.0
# Episode 713: Total Reward = -200.0
# Episode 714: Total Reward = -200.0
# Episode 715: Total Reward = -200.0
# Episode 716: Total Reward = -200.0
# Episode 717: Total Reward = -200.0
# Episode 718: Total Reward = -200.0
# Episode 719: Total Reward = -200.0
# Episode 720: Total Reward = -200.0
# Episode 721: Total Reward = -200.0
# Episode 722: Total Reward = -200.0
# Episode 723: Total Reward = -200.0
# Episode 724: Total Reward = -200.0
# Episode 725: Total Reward = -200.0
# Episode 726: Total Reward = -200.0
# Episode 727: Total Reward = -200.0
# Episode 728: Total Reward = -200.0
# Episode 729: Total Reward = -200.0
# Episode 730: Total Reward = -200.0
# Episode 731: Total Reward = -200.0
# Episode 732: Total Reward = -200.0
# Episode 733: Total Reward = -200.0
# Episode 734: Total Reward = -200.0
# Episode 735: Total Reward = -200.0
# Episode 736: Total Reward = -200.0
# Episode 737: Total Reward = -200.0
# Episode 738: Total Reward = -200.0
# Episode 739: Total Reward = -200.0
# Episode 740: Total Reward = -200.0
# Episode 741: Total Reward = -200.0
# Episode 742: Total Reward = -200.0
# Episode 743: Total Reward = -200.0
# Episode 744: Total Reward = -200.0
# Episode 745: Total Reward = -200.0
# Episode 746: Total Reward = -200.0
# Episode 747: Total Reward = -200.0
# Episode 748: Total Reward = -200.0
# Episode 749: Total Reward = -200.0
# Episode 750: Total Reward = -200.0
# Episode 751: Total Reward = -200.0
# Episode 752: Total Reward = -200.0
# Episode 753: Total Reward = -200.0
# Episode 754: Total Reward = -200.0
# Episode 755: Total Reward = -200.0
# Episode 756: Total Reward = -200.0
# Episode 757: Total Reward = -200.0
# Episode 758: Total Reward = -200.0
# Episode 759: Total Reward = -200.0
# Episode 760: Total Reward = -200.0
# Episode 761: Total Reward = -200.0
# Episode 762: Total Reward = -200.0
# Episode 763: Total Reward = -200.0
# Episode 764: Total Reward = -200.0
# Episode 765: Total Reward = -200.0
# Episode 766: Total Reward = -200.0
# Episode 767: Total Reward = -200.0
# Episode 768: Total Reward = -200.0
# Episode 769: Total Reward = -200.0
# Episode 770: Total Reward = -200.0
# Episode 771: Total Reward = -200.0
# Episode 772: Total Reward = -200.0
# Episode 773: Total Reward = -200.0
# Episode 774: Total Reward = -200.0
# Episode 775: Total Reward = -200.0
# Episode 776: Total Reward = -200.0
# Episode 777: Total Reward = -200.0
# Episode 778: Total Reward = -200.0
# Episode 779: Total Reward = -200.0
# Episode 780: Total Reward = -200.0
# Episode 781: Total Reward = -200.0
# Episode 782: Total Reward = -200.0
# Episode 783: Total Reward = -200.0
# Episode 784: Total Reward = -200.0
# Episode 785: Total Reward = -200.0
# Episode 786: Total Reward = -200.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       1 env = gym.make("MountainCar-v0", render_mode=None)
#       3 neural_network_sarsa = NeuralNetworkSarsa(
#       4     nb_actions=env.action_space.n,
#       5     encode_fct=no_encode,
#    (...)
#       9     loss=nn.MSELoss(),
#      10 )
# ---> 12 _ = neural_network_sarsa.train(
#      13     env=env,
#      14     alpha=0.001,
#      15     gamma=1,
#      16     policy_action_params={},
#      17     policy_update_params={"use_glei": True, "update_frequency": 20},
#      18     network_update_frequency=1,
#      19     nb_episodes=20000,
#      20     verbose=2,
#      21 )
#      22 _ = neural_network_sarsa.evaluate_policy(
#      23     env=env, policy_action_params={"hard_policy": True}, nb_episodes=10, verbose=1
#      24 )
#
# File ~/Documents/vsc-workspace/mountain_car/src/agents/nn_semigrad_sarsa.py:224, in NeuralNetworkSarsa.train(self, env, policy_action_params, policy_update_params, alpha, gamma, seed, nb_episodes, max_step, network_update_frequency, to_evaluate, evaluation_params, evaluation_frequency, verbose)
#     218 # Update network weights
#     219 if (
#     220     network_update_frequency is not None
#     221     and step % network_update_frequency == 0
#     222     and step > 0
#     223 ) or (task_completed or episode_over):
# --> 224     self.update_parameters(alpha)
#     226 # Potentially update the policy parameters
#     227 if (max_step is not None and nb_episodes == 1) or (
#     228     task_completed or episode_over
#     229 ):
#
# File ~/Documents/vsc-workspace/mountain_car/src/agents/nn_semigrad_sarsa.py:139, in NeuralNetworkSarsa.update_parameters(self, alpha)
#     134 # Forward pass
#     135 # predicted_qvalues = self.model(input_batch)
#     136
#     137 # Backward pass
#     138 loss = self.loss(predicted_batch, target_batch)  # Compute the loss
# --> 139 loss.backward()  # Compute the gradients
#     140 self.optimizer.step()  # Update parameters
#     142 # Clear batches
#
# File ~/Library/Caches/pypoetry/virtualenvs/mountain-car-dUPDKyLO-py3.10/lib/python3.10/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/mountain-car-dUPDKyLO-py3.10/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/mountain-car-dUPDKyLO-py3.10/lib/python3.10/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Sandbox

# %%
class SimpleDenseModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.hidden_layer = nn.Linear(hidden_size, hidden_size)
        self.output_layer = nn.Linear(hidden_size, output_size)
        self.relu = nn.LeakyReLU()

    def forward(self, x):
        x = self.input_layer(x)
        x = self.relu(x)
        x = self.hidden_layer(x)
        x = self.relu(x)
        return self.output_layer(x)


model = SimpleDenseModel(3, 8, 1)

# %%
x = torch.tensor(
    [
        [*(0.245, 1.233), 0],
        [*(0.6, 0.045), 1],
        [*(-1.55, 1.233), 2],
    ]
)
print(np.argmax(model(x).detach().numpy().flatten()))
print(model(torch.tensor([*(0.245, 1.233), 0])))
print(model(torch.tensor([*(0.6, 0.045), 1])))
print(model(torch.tensor([*(-1.55, 1.233), 2])))
# Out:
# 2
# tensor([0.4378], grad_fn=<ViewBackward0>)
# tensor([0.4402], grad_fn=<ViewBackward0>)
# tensor([0.4767], grad_fn=<ViewBackward0>)

# %%
x.tolist()
# Out:
# [[0.24500000476837158, 1.2330000400543213, 0.0],
#  [0.6000000238418579, 0.04500000178813934, 1.0],
#  [-1.5499999523162842, 1.2330000400543213, 2.0]]
